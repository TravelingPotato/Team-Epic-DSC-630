# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
nba = pd.read_csv("nba.csv")
nba.head(5)
# Out:
#    Number  Season_Start     Player_Name     Salary Position  Age Team  \
# 0   24304          2017    A.J. Hammons  1312611.0        C   24  DAL
# 1   24165          2017    Aaron Brooks  2116955.0       PG   32  IND
# 2   24289          2017    Aaron Gordon  5504420.0       SF   21  ORL
# 3   24315          2017  Aaron Harrison   365289.0       SG   22  CHO
# 4   24523          2017   Adreian Payne  2022240.0       PF   25  MIN
#
#    Games_Played  Games_Started  Minutes_Played  ...  Free_Throws_Pct  \
# 0            22              0             163  ...            0.450
# 1            65              0             894  ...            0.800
# 2            80             72            2298  ...            0.719
# 3             5              0              17  ...            0.500
# 4            18              0             135  ...            0.737
#
#    Offensive_Rebounds  Defensive_Rebounds  Total_Rebounds  Assists  Steals  \
# ...

# %%
nba.hist(bins = 15, color = "steelblue", edgecolor = "black", linewidth = 1.0, xlabelsize = 8, ylabelsize = 8, grid = False, figsize = (20,20))
plt.show()

# %%
#import seaborn as sns
#sns.pairplot(nba)

# %%
pd.set_option('display.max_columns', 500)
nba.describe()
# Out:
#              Number  Season_Start        Salary         Age  Games_Played  \
# count    486.000000         486.0  4.840000e+02  486.000000    486.000000
# mean   24392.170782        2017.0  6.717244e+06   26.405350     53.783951
# std      171.748286           0.0  7.376188e+06    4.345194     24.835638
# min    24096.000000        2017.0  1.722400e+04   19.000000      1.000000
# 25%    24242.250000        2017.0  1.471382e+06   23.000000     35.250000
# 50%    24392.500000        2017.0  3.343830e+06   26.000000     62.500000
# 75%    24541.750000        2017.0  1.004073e+07   29.000000     75.000000
# max    24690.000000        2017.0  3.468255e+07   40.000000     82.000000
#
#        Games_Started  Minutes_Played  Player_Efficiency_Rating  \
# count     486.000000      486.000000                486.000000
# mean       25.308642     1223.051440                 13.020782
# std        28.715875      842.438143                  5.762420
# ...

# %%
nba.describe(include = "all")
# Out:
#               Number  Season_Start    Player_Name        Salary Position  \
# count     486.000000         486.0            486  4.840000e+02      486
# unique           NaN           NaN            486           NaN        6
# top              NaN           NaN  Kyle Anderson           NaN       SG
# freq             NaN           NaN              1           NaN      106
# mean    24392.170782        2017.0            NaN  6.717244e+06      NaN
# std       171.748286           0.0            NaN  7.376188e+06      NaN
# min     24096.000000        2017.0            NaN  1.722400e+04      NaN
# 25%     24242.250000        2017.0            NaN  1.471382e+06      NaN
# 50%     24392.500000        2017.0            NaN  3.343830e+06      NaN
# 75%     24541.750000        2017.0            NaN  1.004073e+07      NaN
# max     24690.000000        2017.0            NaN  3.468255e+07      NaN
#
#                Age Team  Games_Played  Games_Started  Minutes_Played  \
# ...

# %%
nba
# Out:
#      Number  Season_Start          Player_Name      Salary Position  Age Team  \
# 0     24304          2017         A.J. Hammons   1312611.0        C   24  DAL
# 1     24165          2017         Aaron Brooks   2116955.0       PG   32  IND
# 2     24289          2017         Aaron Gordon   5504420.0       SF   21  ORL
# 3     24315          2017       Aaron Harrison    365289.0       SG   22  CHO
# 4     24523          2017        Adreian Payne   2022240.0       PF   25  MIN
# 5     24343          2017           Al Horford  27734405.0        C   30  BOS
# 6     24366          2017         Al Jefferson   9769821.0        C   32  IND
# 7     24109          2017        Alan Anderson   1315448.0       SF   34  LAC
# 8     24660          2017        Alan Williams   6000000.0        C   24  PHO
# 9     24174          2017           Alec Burks  10845506.0       SG   25  UTA
# 10    24096          2017         Alex Abrines   5725000.0       SG   23  OKC
# ...

# %%
nba_subset = nba[["Player_Name", "Salary", "Assists_Pct", "Box_Plus_Minus", "Field_Goal_Pct", "Player_Efficiency_Rating", "Points", "Three_Pointers_Pct", "True_Shooting_Pct", "Two_Pointers_Pct", "Usage_Pct"]]

# %%
nba_subset
# Out:
#              Player_Name      Salary  Assists_Pct  Box_Plus_Minus  \
# 0           A.J. Hammons   1312611.0          3.8            -5.6
# 1           Aaron Brooks   2116955.0         20.7            -4.6
# 2           Aaron Gordon   5504420.0         10.5            -0.7
# 3         Aaron Harrison    365289.0         22.6           -11.6
# 4          Adreian Payne   2022240.0          8.0            -1.5
# 5             Al Horford  27734405.0         24.4             3.1
# 6           Al Jefferson   9769821.0         11.0            -3.1
# 7          Alan Anderson   1315448.0          4.9            -4.9
# 8          Alan Williams   6000000.0          5.2            -1.7
# 9             Alec Burks  10845506.0          7.5            -4.2
# 10          Alex Abrines   5725000.0          5.5            -2.5
# 11              Alex Len   4187599.0          4.2            -1.8
# 12        Alex Poythress     38362.0          5.1            -2.5
# ...

# %%
nba_subset.hist(bins = 15, color = "steelblue", edgecolor = "black", linewidth = 1.0, xlabelsize = 8, ylabelsize = 8, grid = False, figsize = (20,20))
plt.show()

# %%
import seaborn as sns
sns.pairplot(nba_subset)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-4e80340ba617> in <module>
#       1 import seaborn as sns
# ----> 2 sns.pairplot(nba_subset)
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, dropna, plot_kws, diag_kws, grid_kws, size)
#    2105     if grid.square_grid:
#    2106         if diag_kind == "hist":
# -> 2107             grid.map_diag(plt.hist, **diag_kws)
#    2108         elif diag_kind == "kde":
#    2109             diag_kws.setdefault("shade", True)
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in map_diag(self, func, **kwargs)
#    1397                     color = fixed_color
#    1398
# -> 1399                 func(data_k, label=label_k, color=color, **kwargs)
#    1400
#    1401             self._clean_axis(ax)
#
# ...

# %%
pd.set_option('display.max_columns', 500)
nba_subset.describe()
# Out:
#              Salary  Assists_Pct  Box_Plus_Minus  Field_Goal_Pct  \
# count  4.840000e+02   486.000000      486.000000      485.000000
# mean   6.717244e+06    13.067695       -1.701852        0.441268
# std    7.376188e+06     9.172849        4.220521        0.099094
# min    1.722400e+04     0.000000      -26.900000        0.000000
# 25%    1.471382e+06     6.525000       -3.600000        0.399000
# 50%    3.343830e+06    10.100000       -1.500000        0.442000
# 75%    1.004073e+07    17.575000        0.375000        0.485000
# max    3.468255e+07    57.300000       15.600000        1.000000
#
#        Player_Efficiency_Rating       Points  Three_Pointers_Pct  \
# count                486.000000   486.000000          450.000000
# mean                  13.020782   534.471193            0.299342
# std                    5.762420   487.642042            0.131183
# min                  -17.600000     0.000000            0.000000
# ...

# %%
nba_subset.describe(include = "all")
# Out:
#           Player_Name        Salary  Assists_Pct  Box_Plus_Minus  \
# count             486  4.840000e+02   486.000000      486.000000
# unique            486           NaN          NaN             NaN
# top     Kyle Anderson           NaN          NaN             NaN
# freq                1           NaN          NaN             NaN
# mean              NaN  6.717244e+06    13.067695       -1.701852
# std               NaN  7.376188e+06     9.172849        4.220521
# min               NaN  1.722400e+04     0.000000      -26.900000
# 25%               NaN  1.471382e+06     6.525000       -3.600000
# 50%               NaN  3.343830e+06    10.100000       -1.500000
# 75%               NaN  1.004073e+07    17.575000        0.375000
# max               NaN  3.468255e+07    57.300000       15.600000
#
#         Field_Goal_Pct  Player_Efficiency_Rating       Points  \
# count       485.000000                486.000000   486.000000
# ...

# %% [markdown]
# Corr Heatmap of all features

# %%
import numpy as np

corr = nba.corr()

f, ax = plt.subplots(figsize=(11, 9))

mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr, cmap=cmap, mask=mask, center=0,
           square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# Corr Heatmap of nba_subset

# %%
corr = nba_subset.corr()

f, ax = plt.subplots(figsize=(11, 9))

mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr, cmap=cmap, mask=mask, center=0,
           square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# nba_subset2 uses the features from feature selection doc with a score higher than 2 minus "player name" and "team"

# %%
nba_subset2 = nba[["Age", "Player_Efficiency_Rating", "Minutes_Played", "Blocks", "Free_Throws_Attempted", "Turnovers_Pct", "Two_Pointers_Attempted", "Steals", "Points", "Assists_Pct", "Games_Started","Games_Played", "Total_Rebounds", "Field_Goals_Attempted", "Field_Goals", "Defensive_Box_Plus_Minus", "Defensive_Rebound_Pct", "Usage_Pct", "Free-Throws"]]

# %%
corr = nba_subset2.corr()

f, ax = plt.subplots(figsize=(11, 9))

mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

sns.heatmap(corr, cmap=cmap, mask=mask, center=0,
           square=True, linewidths=.5,cbar_kws={"shrink": .5})

# %%
nba_subset3 = nba_subset2.drop("Minutes_Played", axis=1)
nba_subset3 = nba_subset3.drop("Two_Pointers_Attempted", axis=1)
nba_subset3 = nba_subset3.drop("Points", axis=1)
nba_subset3 = nba_subset3.drop("Free_Throws_Attempted", axis=1)
nba_subset3 = nba_subset3.drop("Field_Goals_Attempted", axis=1)

# %%
corr = nba_subset3.corr()

f, ax = plt.subplots(figsize=(11, 9))

mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

sns.heatmap(corr, cmap=cmap, mask=mask, center=0,
           square=True, linewidths=.5,
            annot=True,cbar_kws={"shrink": .5})

# %%
nba_used = nba_subset3
nba_used['Salary'] = nba["Salary"]
nba_used = nba_used.dropna()
nba_used.shape
# Out:
# (483, 15)

# %%
from sklearn.linear_model import LinearRegression
x = nba_used.drop('Salary', axis=1)
y = nba_used['Salary']

model = LinearRegression().fit(x,y)

r_sq = model.score(x,y)

r_sq
# Out:
# 0.6190523411916885
