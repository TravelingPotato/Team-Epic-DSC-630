# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd

# %%
def pull_stats(year):   

    # create url based on selected year
    url = "https://www.basketball-reference.com/leagues/NBA_{}_per_game.html".format(year)
    soup = BeautifulSoup(urlopen(url))

    headers = [th.getText() for th in soup.findAll('tr')[0].findAll('th')]

    # remove the 'rank' column
    headers = headers[1:]

    # find rows except for the header row
    rows = soup.findAll('tr')[1:]
    
    # format data
    player_stats = [[td.getText() for td in rows[i].findAll('td')]
                for i in range(len(rows))]
    
    # create pandas dataframe
    stats = pd.DataFrame(player_stats, columns = headers)
    
    # create a year column
    stats['Year'] = year
    
    return stats

# %%
def pull_salary(year, pages):
    full = []
    
    for i in range(1,pages+1):
        url = "http://www.espn.com/nba/salaries/_/year/{}/page/{}".format(year, i)

        soup = BeautifulSoup(urlopen(url))

        headers = [td.getText() for td in soup.findAll('tr')[0].findAll('td')]

        rows = soup.findAll('tr')[1:]

        player_salary = [[td.getText() for td in rows[i].findAll('td')]
                    for i in range(len(rows))]

        salary = pd.DataFrame(player_salary, columns = headers)
        salary['Year'] = year

        for i in range(len(salary)):
            salary['NAME'][i] = salary['NAME'][i].split(',')[0]
        
        full.append(salary)
    
    full = pd.concat(full)
    
    return full

# %%
sal = pull_salary(2019,13)
sta = pull_stats(2019)
# Out:
# http://www.espn.com/nba/salaries/_/year/2019/page/1
# C:\Users\ande5\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# http://www.espn.com/nba/salaries/_/year/2019/page/2
# http://www.espn.com/nba/salaries/_/year/2019/page/3
# http://www.espn.com/nba/salaries/_/year/2019/page/4
# http://www.espn.com/nba/salaries/_/year/2019/page/5
# http://www.espn.com/nba/salaries/_/year/2019/page/6
# http://www.espn.com/nba/salaries/_/year/2019/page/7
# http://www.espn.com/nba/salaries/_/year/2019/page/8
# http://www.espn.com/nba/salaries/_/year/2019/page/9
# http://www.espn.com/nba/salaries/_/year/2019/page/10
# http://www.espn.com/nba/salaries/_/year/2019/page/11
# http://www.espn.com/nba/salaries/_/year/2019/page/12

# %%
len(sal)
# Out:
# 516

# %%
sta.to_csv("stats.csv")
sal.to_csv("salary.csv")

# %%
for i in range(len(sta)):
    player = sta['Player'][i]
    index = sal[sal['NAME']==player].index
    print(index)
    print(player)
# Out:
# Int64Index([], dtype='int64')
# Álex Abrines
# Int64Index([], dtype='int64')
# Quincy Acy
# Int64Index([37], dtype='int64')
# Jaylen Adams
# Int64Index([27], dtype='int64')
# Steven Adams
# Int64Index([16], dtype='int64')
# Bam Adebayo
# Int64Index([], dtype='int64')
# Deng Adel
# Int64Index([], dtype='int64')
# DeVaughn Akoon-Purcell
# Int64Index([38], dtype='int64')
# LaMarcus Aldridge
# Int64Index([], dtype='int64')
# Rawle Alkins
# Int64Index([19], dtype='int64')
# Grayson Allen
# Int64Index([23], dtype='int64')
# Jarrett Allen
# Int64Index([], dtype='int64')
# Kadeem Allen
# Int64Index([6], dtype='int64')
# Al-Farouq Aminu
# Int64Index([36], dtype='int64')
# Justin Anderson
# Int64Index([18], dtype='int64')
# Kyle Anderson
# Int64Index([1], dtype='int64')
# Ryan Anderson
# Int64Index([1], dtype='int64')
# Ryan Anderson
# Int64Index([1], dtype='int64')
# Ryan Anderson
# Int64Index([14], dtype='int64')
# Ike Anigbogu
# Int64Index([28], dtype='int64')
# Giannis Antetokounmpo
# Int64Index([], dtype='int64')
# Kostas Antetokounmpo
# Int64Index([7], dtype='int64')
# Carmelo Anthony
# Int64Index([], dtype='int64')
# None
# Int64Index([22], dtype='int64')
# OG Anunoby
# Int64Index([29], dtype='int64')
# Ryan Arcidiacono
# Int64Index([31], dtype='int64')
# Trevor Ariza
# Int64Index([31], dtype='int64')
# Trevor Ariza
# Int64Index([31], dtype='int64')
# Trevor Ariza
# Int64Index([41], dtype='int64')
# D.J. Augustin
# Int64Index([26], dtype='int64')
# Deandre Ayton
# Int64Index([37], dtype='int64')
# Dwayne Bacon
# Int64Index([40], dtype='int64')
# Marvin Bagley III
# Int64Index([0], dtype='int64')
# Ron Baker
# Int64Index([0], dtype='int64')
# Ron Baker
# Int64Index([0], dtype='int64')
# Ron Baker
# Int64Index([], dtype='int64')
# Wade Baldwin
# Int64Index([37], dtype='int64')
# Lonzo Ball
# Int64Index([2], dtype='int64')
# Mo Bamba
# Int64Index([26], dtype='int64')
# J.J. Barea
# Int64Index([31], dtype='int64')
# Harrison Barnes
# Int64Index([31], dtype='int64')
# Harrison Barnes
# Int64Index([31], dtype='int64')
# Harrison Barnes
# Int64Index([24], dtype='int64')
# Will Barton
# Int64Index([14], dtype='int64')
# Keita Bates-Diop
# Int64Index([34], dtype='int64')
# Nicolas Batum
# Int64Index([20], dtype='int64')
# Jerryd Bayless
# Int64Index([36], dtype='int64')
# Aron Baynes
# Int64Index([14], dtype='int64')
# Kent Bazemore
# Int64Index([22], dtype='int64')
# Bradley Beal
# Int64Index([], dtype='int64')
# None
# Int64Index([34], dtype='int64')
# Malik Beasley
# Int64Index([31], dtype='int64')
# Michael Beasley
# Int64Index([14], dtype='int64')
# Marco Belinelli
# Int64Index([41], dtype='int64')
# Jordan Bell
# Int64Index([11], dtype='int64')
# DeAndre' Bembry
# Int64Index([5], dtype='int64')
# Dragan Bender
# Int64Index([], dtype='int64')
# Dairis Bertāns
# Int64Index([], dtype='int64')
# Dāvis Bertāns
# Int64Index([38], dtype='int64')
# Patrick Beverley
# Int64Index([5], dtype='int64')
# Khem Birch
# Int64Index([20], dtype='int64')
# Bismack Biyombo
# Int64Index([9], dtype='int64')
# Nemanja Bjelica
# Int64Index([28], dtype='int64')
# Antonio Blakeney
# Int64Index([33], dtype='int64')
# Eric Bledsoe
# Int64Index([], dtype='int64')
# Jaron Blossomgame
# Int64Index([], dtype='int64')
# Bogdan Bogdanović
# Int64Index([], dtype='int64')
# Bojan Bogdanović
# Int64Index([36], dtype='int64')
# Andrew Bogut
# Int64Index([42], dtype='int64')
# Jonah Bolden
# Int64Index([40], dtype='int64')
# Isaac Bonga
# Int64Index([], dtype='int64')
# None
# Int64Index([1], dtype='int64')
# Devin Booker
# Int64Index([31], dtype='int64')
# Chris Boucher
# Int64Index([20], dtype='int64')
# Avery Bradley
# Int64Index([20], dtype='int64')
# Avery Bradley
# Int64Index([20], dtype='int64')
# Avery Bradley
# Int64Index([1], dtype='int64')
# Tony Bradley
# Int64Index([24], dtype='int64')
# Corey Brewer
# Int64Index([24], dtype='int64')
# Corey Brewer
# Int64Index([24], dtype='int64')
# Corey Brewer
# Int64Index([30], dtype='int64')
# Mikal Bridges
# Int64Index([6], dtype='int64')
# Miles Bridges
# Int64Index([7], dtype='int64')
# Isaiah Briscoe
# Int64Index([15], dtype='int64')
# Ryan Broekhoff
# Int64Index([36], dtype='int64')
# Malcolm Brogdon
# Int64Index([39], dtype='int64')
# Dillon Brooks
# Int64Index([4], dtype='int64')
# MarShon Brooks
# Int64Index([12], dtype='int64')
# Bruce Brown
# Int64Index([37], dtype='int64')
# Jaylen Brown
# Int64Index([], dtype='int64')
# Lorenzo Brown
# Int64Index([9], dtype='int64')
# Sterling Brown
# Int64Index([25], dtype='int64')
# Troy Brown Jr.
# Int64Index([35], dtype='int64')
# Jalen Brunson
# Int64Index([42], dtype='int64')
# Thomas Bryant
# Int64Index([38], dtype='int64')
# Reggie Bullock
# Int64Index([38], dtype='int64')
# Reggie Bullock
# Int64Index([38], dtype='int64')
# Reggie Bullock
# Int64Index([], dtype='int64')
# None
# Int64Index([31], dtype='int64')
# Trey Burke
# Int64Index([31], dtype='int64')
# Trey Burke
# Int64Index([31], dtype='int64')
# Trey Burke
# Int64Index([30], dtype='int64')
# Alec Burks
# Int64Index([30], dtype='int64')
# Alec Burks
# Int64Index([30], dtype='int64')
# Alec Burks
# Int64Index([30], dtype='int64')
# Alec Burks
# Int64Index([], dtype='int64')
# Deonte Burton
# Int64Index([0], dtype='int64')
# Jimmy Butler
# Int64Index([0], dtype='int64')
# Jimmy Butler
# Int64Index([0], dtype='int64')
# Jimmy Butler
# Int64Index([23], dtype='int64')
# Bruno Caboclo
# Int64Index([], dtype='int64')
# José Calderón
# Int64Index([22], dtype='int64')
# Kentavious Caldwell-Pope
# Int64Index([13], dtype='int64')
# Isaiah Canaan
# Int64Index([13], dtype='int64')
# Isaiah Canaan
# Int64Index([13], dtype='int64')
# Isaiah Canaan
# Int64Index([13], dtype='int64')
# Isaiah Canaan
# Int64Index([1], dtype='int64')
# Clint Capela
# Int64Index([29], dtype='int64')
# DeMarre Carroll
# Int64Index([6], dtype='int64')
# Jevon Carter
# Int64Index([34], dtype='int64')
# Vince Carter
# Int64Index([11], dtype='int64')
# Wendell Carter Jr.
# Int64Index([], dtype='int64')
# Michael Carter-Williams
# Int64Index([], dtype='int64')
# Michael Carter-Williams
# Int64Index([], dtype='int64')
# Michael Carter-Williams
# Int64Index([], dtype='int64')
# Alex Caruso
# Int64Index([2], dtype='int64')
# Omri Casspi
# Int64Index([4], dtype='int64')
# Willie Cauley-Stein
# Int64Index([], dtype='int64')
# Troy Caupain
# Int64Index([], dtype='int64')
# Tyler Cavanaugh
# Int64Index([31], dtype='int64')
# Tyson Chandler
# Int64Index([31], dtype='int64')
# Tyson Chandler
# Int64Index([31], dtype='int64')
# Tyson Chandler
# Int64Index([], dtype='int64')
# None
# Int64Index([9], dtype='int64')
# Wilson Chandler
# Int64Index([9], dtype='int64')
# Wilson Chandler
# Int64Index([9], dtype='int64')
# Wilson Chandler
# Int64Index([], dtype='int64')
# Joe Chealey
# Int64Index([], dtype='int64')
# Chris Chiozza
# Int64Index([7], dtype='int64')
# Marquese Chriss
# Int64Index([7], dtype='int64')
# Marquese Chriss
# Int64Index([7], dtype='int64')
# Marquese Chriss
# Int64Index([22], dtype='int64')
# Gary Clark
# Int64Index([31], dtype='int64')
# Ian Clark
# Int64Index([14], dtype='int64')
# Jordan Clarkson
# Int64Index([7], dtype='int64')
# John Collins
# Int64Index([28], dtype='int64')
# Zach Collins
# Int64Index([3], dtype='int64')
# Darren Collison
# Int64Index([], dtype='int64')
# Bonzie Colson
# Int64Index([8], dtype='int64')
# Mike Conley
# Int64Index([9], dtype='int64')
# Pat Connaughton
# Int64Index([31], dtype='int64')
# Quinn Cook
# Int64Index([31], dtype='int64')
# DeMarcus Cousins
# Int64Index([41], dtype='int64')
# Robert Covington
# Int64Index([41], dtype='int64')
# Robert Covington
# Int64Index([41], dtype='int64')
# Robert Covington
# Int64Index([12], dtype='int64')
# Allen Crabbe
# Int64Index([25], dtype='int64')
# Torrey Craig
# Int64Index([8], dtype='int64')
# Jamal Crawford
# Int64Index([], dtype='int64')
# Mitch Creek
# Int64Index([], dtype='int64')
# Mitch Creek
# Int64Index([], dtype='int64')
# Mitch Creek
# Int64Index([], dtype='int64')
# None
# Int64Index([39], dtype='int64')
# Jae Crowder
# Int64Index([40], dtype='int64')
# Dante Cunningham
# Int64Index([22], dtype='int64')
# Seth Curry
# Int64Index([0], dtype='int64')
# Stephen Curry
# Int64Index([4], dtype='int64')
# Troy Daniels
# Int64Index([23], dtype='int64')
# Anthony Davis
# Int64Index([], dtype='int64')
# Deyonta Davis
# Int64Index([7], dtype='int64')
# Ed Davis
# Int64Index([], dtype='int64')
# Tyler Davis
# Int64Index([42], dtype='int64')
# Dewayne Dedmon
# Int64Index([24], dtype='int64')
# Sam Dekker
# Int64Index([24], dtype='int64')
# Sam Dekker
# Int64Index([24], dtype='int64')
# Sam Dekker
# Int64Index([], dtype='int64')
# Ángel Delgado
# Int64Index([5], dtype='int64')
# Matthew Dellavedova
# Int64Index([5], dtype='int64')
# Matthew Dellavedova
# Int64Index([5], dtype='int64')
# Matthew Dellavedova
# Int64Index([12], dtype='int64')
# Luol Deng
# Int64Index([15], dtype='int64')
# DeMar DeRozan
# Int64Index([], dtype='int64')
# Marcus Derrickson
# Int64Index([28], dtype='int64')
# Cheick Diallo
# Int64Index([3], dtype='int64')
# Hamidou Diallo
# Int64Index([30], dtype='int64')
# Gorgui Dieng
# Int64Index([3], dtype='int64')
# Spencer Dinwiddie
# Int64Index([], dtype='int64')
# None
# Int64Index([41], dtype='int64')
# Donte DiVincenzo
# Int64Index([], dtype='int64')
# Luka Dončić
# Int64Index([40], dtype='int64')
# Tyler Dorsey
# Int64Index([40], dtype='int64')
# Tyler Dorsey
# Int64Index([40], dtype='int64')
# Tyler Dorsey
# Int64Index([6], dtype='int64')
# Damyean Dotson
# Int64Index([], dtype='int64')
# PJ Dozier
# Int64Index([], dtype='int64')
# Goran Dragić
# Int64Index([24], dtype='int64')
# Andre Drummond
# Int64Index([7], dtype='int64')
# Jared Dudley
# Int64Index([17], dtype='int64')
# Kris Dunn
# Int64Index([11], dtype='int64')
# Kevin Durant
# Int64Index([], dtype='int64')
# Trevon Duval
# Int64Index([], dtype='int64')
# Vince Edwards
# Int64Index([34], dtype='int64')
# Henry Ellenson
# Int64Index([34], dtype='int64')
# Henry Ellenson
# Int64Index([34], dtype='int64')
# Henry Ellenson
# Int64Index([5], dtype='int64')
# Wayne Ellington
# Int64Index([5], dtype='int64')
# Wayne Ellington
# Int64Index([5], dtype='int64')
# Wayne Ellington
# Int64Index([19], dtype='int64')
# Joel Embiid
# Int64Index([], dtype='int64')
# James Ennis
# Int64Index([], dtype='int64')
# James Ennis
# Int64Index([], dtype='int64')
# James Ennis
# Int64Index([], dtype='int64')
# Drew Eubanks
# Int64Index([8], dtype='int64')
# Jacob Evans
# Int64Index([3], dtype='int64')
# Jawun Evans
# Int64Index([3], dtype='int64')
# Jawun Evans
# Int64Index([3], dtype='int64')
# Jawun Evans
# Int64Index([16], dtype='int64')
# Tyreke Evans
# Int64Index([], dtype='int64')
# None
# Int64Index([6], dtype='int64')
# Dante Exum
# Int64Index([19], dtype='int64')
# Kenneth Faried
# Int64Index([19], dtype='int64')
# Kenneth Faried
# Int64Index([19], dtype='int64')
# Kenneth Faried
# Int64Index([22], dtype='int64')
# Derrick Favors
# Int64Index([], dtype='int64')
# Cristiano Felício
# Int64Index([4], dtype='int64')
# Raymond Felton
# Int64Index([18], dtype='int64')
# Terrance Ferguson
# Int64Index([14], dtype='int64')
# Yogi Ferrell
# Int64Index([38], dtype='int64')
# Dorian Finney-Smith
# Int64Index([9], dtype='int64')
# Bryn Forbes
# Int64Index([18], dtype='int64')
# Evan Fournier
# Int64Index([24], dtype='int64')
# De'Aaron Fox
# Int64Index([], dtype='int64')
# Melvin Frazier
# Int64Index([40], dtype='int64')
# Tim Frazier
# Int64Index([40], dtype='int64')
# Tim Frazier
# Int64Index([40], dtype='int64')
# Tim Frazier
# Int64Index([39], dtype='int64')
# Jimmer Fredette
# Int64Index([30], dtype='int64')
# Channing Frye
# Int64Index([22], dtype='int64')
# Markelle Fultz
# Int64Index([41], dtype='int64')
# Danilo Gallinari
# Int64Index([4], dtype='int64')
# Langston Galloway
# Int64Index([], dtype='int64')
# Billy Garrett
# Int64Index([29], dtype='int64')
# Marc Gasol
# Int64Index([29], dtype='int64')
# Marc Gasol
# Int64Index([29], dtype='int64')
# Marc Gasol
# Int64Index([], dtype='int64')
# None
# Int64Index([35], dtype='int64')
# Pau Gasol
# Int64Index([35], dtype='int64')
# Pau Gasol
# Int64Index([35], dtype='int64')
# Pau Gasol
# Int64Index([42], dtype='int64')
# Rudy Gay
# Int64Index([7], dtype='int64')
# Paul George
# Int64Index([42], dtype='int64')
# Taj Gibson
# Int64Index([], dtype='int64')
# Harry Giles
# Int64Index([41], dtype='int64')
# Shai Gilgeous-Alexander
# Int64Index([35], dtype='int64')
# Rudy Gobert
# Int64Index([20], dtype='int64')
# Brandon Goodwin
# Int64Index([40], dtype='int64')
# Aaron Gordon
# Int64Index([4], dtype='int64')
# Eric Gordon
# Int64Index([2], dtype='int64')
# Marcin Gortat
# Int64Index([41], dtype='int64')
# Devonte' Graham
# Int64Index([33], dtype='int64')
# Treveon Graham
# Int64Index([17], dtype='int64')
# Jerami Grant
# Int64Index([29], dtype='int64')
# Jerian Grant
# Int64Index([], dtype='int64')
# Donte Grantham
# Int64Index([2], dtype='int64')
# Danny Green
# Int64Index([16], dtype='int64')
# Draymond Green
# Int64Index([27], dtype='int64')
# Gerald Green
# Int64Index([33], dtype='int64')
# JaMychal Green
# Int64Index([33], dtype='int64')
# JaMychal Green
# Int64Index([33], dtype='int64')
# JaMychal Green
# Int64Index([], dtype='int64')
# None
# Int64Index([19], dtype='int64')
# Jeff Green
# Int64Index([4], dtype='int64')
# Blake Griffin
# Int64Index([26], dtype='int64')
# Daniel Hamilton
# Int64Index([], dtype='int64')
# Dusty Hannahs
# Int64Index([6], dtype='int64')
# Tim Hardaway Jr.
# Int64Index([6], dtype='int64')
# Tim Hardaway Jr.
# Int64Index([6], dtype='int64')
# Tim Hardaway Jr.
# Int64Index([9], dtype='int64')
# James Harden
# Int64Index([36], dtype='int64')
# Maurice Harkless
# Int64Index([19], dtype='int64')
# Montrezl Harrell
# Int64Index([29], dtype='int64')
# Devin Harris
# Int64Index([24], dtype='int64')
# Gary Harris
# Int64Index([24], dtype='int64')
# Joe Harris
# Int64Index([35], dtype='int64')
# Tobias Harris
# Int64Index([35], dtype='int64')
# Tobias Harris
# Int64Index([35], dtype='int64')
# Tobias Harris
# Int64Index([37], dtype='int64')
# Andrew Harrison
# Int64Index([37], dtype='int64')
# Andrew Harrison
# Int64Index([37], dtype='int64')
# Andrew Harrison
# Int64Index([37], dtype='int64')
# Andrew Harrison
# Int64Index([33], dtype='int64')
# Shaquille Harrison
# Int64Index([6], dtype='int64')
# Josh Hart
# Int64Index([11], dtype='int64')
# Isaiah Hartenstein
# Int64Index([16], dtype='int64')
# Udonis Haslem
# Int64Index([5], dtype='int64')
# Gordon Hayward
# Int64Index([31], dtype='int64')
# John Henson
# Int64Index([], dtype='int64')
# Juan Hernangómez
# Int64Index([], dtype='int64')
# None
# Int64Index([], dtype='int64')
# Willy Hernangómez
# Int64Index([11], dtype='int64')
# Mario Hezonja
# Int64Index([], dtype='int64')
# Isaiah Hicks
# Int64Index([23], dtype='int64')
# Buddy Hield
# Int64Index([], dtype='int64')
# Haywood Highsmith
# Int64Index([], dtype='int64')
# Nenê
# Int64Index([8], dtype='int64')
# George Hill
# Int64Index([8], dtype='int64')
# George Hill
# Int64Index([8], dtype='int64')
# George Hill
# Int64Index([18], dtype='int64')
# Solomon Hill
# Int64Index([29], dtype='int64')
# Aaron Holiday
# Int64Index([17], dtype='int64')
# Jrue Holiday
# Int64Index([12], dtype='int64')
# Justin Holiday
# Int64Index([12], dtype='int64')
# Justin Holiday
# Int64Index([12], dtype='int64')
# Justin Holiday
# Int64Index([], dtype='int64')
# John Holland
# Int64Index([42], dtype='int64')
# Rondae Hollis-Jefferson
# Int64Index([17], dtype='int64')
# Richaun Holmes
# Int64Index([34], dtype='int64')
# Rodney Hood
# Int64Index([34], dtype='int64')
# Rodney Hood
# Int64Index([34], dtype='int64')
# Rodney Hood
# Int64Index([13], dtype='int64')
# Al Horford
# Int64Index([], dtype='int64')
# Danuel House
# Int64Index([33], dtype='int64')
# Dwight Howard
# Int64Index([11], dtype='int64')
# Kevin Huerter
# Int64Index([], dtype='int64')
# Isaac Humphries
# Int64Index([], dtype='int64')
# None
# Int64Index([], dtype='int64')
# R.J. Hunter
# Int64Index([26], dtype='int64')
# Chandler Hutchison
# Int64Index([39], dtype='int64')
# Serge Ibaka
# Int64Index([26], dtype='int64')
# Andre Iguodala
# Int64Index([], dtype='int64')
# Ersan İlyasova
# Int64Index([5], dtype='int64')
# Joe Ingles
# Int64Index([], dtype='int64')
# Andre Ingram
# Int64Index([22], dtype='int64')
# Brandon Ingram
# Int64Index([2], dtype='int64')
# Kyrie Irving
# Int64Index([1], dtype='int64')
# Jonathan Isaac
# Int64Index([], dtype='int64')
# Wesley Iwundu
# Int64Index([], dtype='int64')
# Demetrius Jackson
# Int64Index([19], dtype='int64')
# Frank Jackson
# Int64Index([20], dtype='int64')
# Jaren Jackson Jr.
# Int64Index([16], dtype='int64')
# Josh Jackson
# Int64Index([19], dtype='int64')
# Justin Jackson
# Int64Index([19], dtype='int64')
# Justin Jackson
# Int64Index([19], dtype='int64')
# Justin Jackson
# Int64Index([19], dtype='int64')
# Reggie Jackson
# Int64Index([2], dtype='int64')
# LeBron James
# Int64Index([], dtype='int64')
# Amile Jefferson
# Int64Index([29], dtype='int64')
# John Jenkins
# Int64Index([29], dtype='int64')
# John Jenkins
# Int64Index([29], dtype='int64')
# John Jenkins
# Int64Index([], dtype='int64')
# None
# Int64Index([22], dtype='int64')
# Jonas Jerebko
# Int64Index([9], dtype='int64')
# Alize Johnson
# Int64Index([9], dtype='int64')
# Amir Johnson
# Int64Index([], dtype='int64')
# B.J. Johnson
# Int64Index([], dtype='int64')
# B.J. Johnson
# Int64Index([], dtype='int64')
# B.J. Johnson
# Int64Index([37], dtype='int64')
# James Johnson
# Int64Index([22], dtype='int64')
# Stanley Johnson
# Int64Index([22], dtype='int64')
# Stanley Johnson
# Int64Index([22], dtype='int64')
# Stanley Johnson
# Int64Index([5], dtype='int64')
# Tyler Johnson
# Int64Index([5], dtype='int64')
# Tyler Johnson
# Int64Index([5], dtype='int64')
# Tyler Johnson
# Int64Index([15], dtype='int64')
# Wesley Johnson
# Int64Index([15], dtype='int64')
# Wesley Johnson
# Int64Index([15], dtype='int64')
# Wesley Johnson
# Int64Index([], dtype='int64')
# Nikola Jokić
# Int64Index([41], dtype='int64')
# Damian Jones
# Int64Index([15], dtype='int64')
# Derrick Jones Jr.
# Int64Index([], dtype='int64')
# Jalen Jones
# Int64Index([], dtype='int64')
# Jemerrio Jones
# Int64Index([], dtype='int64')
# Terrence Jones
# Int64Index([2], dtype='int64')
# Tyus Jones
# Int64Index([37], dtype='int64')
# DeAndre Jordan
# Int64Index([37], dtype='int64')
# DeAndre Jordan
# Int64Index([37], dtype='int64')
# DeAndre Jordan
# Int64Index([30], dtype='int64')
# Cory Joseph
# Int64Index([29], dtype='int64')
# Frank Kaminsky
# Int64Index([28], dtype='int64')
# Enes Kanter
# Int64Index([28], dtype='int64')
# Enes Kanter
# Int64Index([28], dtype='int64')
# Enes Kanter
# Int64Index([2], dtype='int64')
# Luke Kennard
# Int64Index([], dtype='int64')
# None
# Int64Index([7], dtype='int64')
# Michael Kidd-Gilchrist
# Int64Index([], dtype='int64')
# George King
# Int64Index([17], dtype='int64')
# Maxi Kleber
# Int64Index([39], dtype='int64')
# Brandon Knight
# Int64Index([39], dtype='int64')
# Brandon Knight
# Int64Index([39], dtype='int64')
# Brandon Knight
# Int64Index([], dtype='int64')
# Kevin Knox
# Int64Index([39], dtype='int64')
# Furkan Korkmaz
# Int64Index([15], dtype='int64')
# Luke Kornet
# Int64Index([34], dtype='int64')
# Kyle Korver
# Int64Index([34], dtype='int64')
# Kyle Korver
# Int64Index([34], dtype='int64')
# Kyle Korver
# Int64Index([15], dtype='int64')
# Kosta Koufos
# Int64Index([16], dtype='int64')
# Rodions Kurucs
# Int64Index([0], dtype='int64')
# Kyle Kuzma
# Int64Index([], dtype='int64')
# Skal Labissière
# Int64Index([], dtype='int64')
# Skal Labissière
# Int64Index([], dtype='int64')
# Skal Labissière
# Int64Index([35], dtype='int64')
# Jeremy Lamb
# Int64Index([4], dtype='int64')
# Zach LaVine
# Int64Index([30], dtype='int64')
# Jake Layman
# Int64Index([4], dtype='int64')
# T.J. Leaf
# Int64Index([17], dtype='int64')
# Courtney Lee
# Int64Index([17], dtype='int64')
# Courtney Lee
# Int64Index([17], dtype='int64')
# Courtney Lee
# Int64Index([], dtype='int64')
# Damion Lee
# Int64Index([], dtype='int64')
# Walt Lemon Jr.
# Int64Index([13], dtype='int64')
# Alex Len
# Int64Index([], dtype='int64')
# None
# Int64Index([36], dtype='int64')
# Kawhi Leonard
# Int64Index([38], dtype='int64')
# Meyers Leonard
# Int64Index([0], dtype='int64')
# Jon Leuer
# Int64Index([41], dtype='int64')
# Caris LeVert
# Int64Index([14], dtype='int64')
# Damian Lillard
# Int64Index([27], dtype='int64')
# Jeremy Lin
# Int64Index([27], dtype='int64')
# Jeremy Lin
# Int64Index([27], dtype='int64')
# Jeremy Lin
# Int64Index([25], dtype='int64')
# Shaun Livingston
# Int64Index([], dtype='int64')
# Zach Lofton
# Int64Index([20], dtype='int64')
# Kevon Looney
# Int64Index([40], dtype='int64')
# Brook Lopez
# Int64Index([40], dtype='int64')
# Robin Lopez
# Int64Index([30], dtype='int64')
# Kevin Love
# Int64Index([6], dtype='int64')
# Kyle Lowry
# Int64Index([], dtype='int64')
# Jordan Loyd
# Int64Index([], dtype='int64')
# Kalin Lucas
# Int64Index([], dtype='int64')
# Timothé Luwawu-Cabarrot
# Int64Index([], dtype='int64')
# Timothé Luwawu-Cabarrot
# Int64Index([], dtype='int64')
# Timothé Luwawu-Cabarrot
# Int64Index([30], dtype='int64')
# Tyler Lydon
# Int64Index([42], dtype='int64')
# Trey Lyles
# Int64Index([], dtype='int64')
# Scott Machado
# Int64Index([1], dtype='int64')
# Shelvin Mack
# Int64Index([1], dtype='int64')
# Shelvin Mack
# Int64Index([1], dtype='int64')
# Shelvin Mack
# Int64Index([], dtype='int64')
# None
# Int64Index([], dtype='int64')
# Daryl Macon
# Int64Index([], dtype='int64')
# J.P. Macura
# Int64Index([27], dtype='int64')
# Ian Mahinmi
# Int64Index([20], dtype='int64')
# Thon Maker
# Int64Index([20], dtype='int64')
# Thon Maker
# Int64Index([20], dtype='int64')
# Thon Maker
# Int64Index([], dtype='int64')
# Boban Marjanović
# Int64Index([], dtype='int64')
# Boban Marjanović
# Int64Index([], dtype='int64')
# Boban Marjanović
# Int64Index([6], dtype='int64')
# Lauri Markkanen
# Int64Index([3], dtype='int64')
# Jarell Martin
# Int64Index([11], dtype='int64')
# Frank Mason III
# Int64Index([], dtype='int64')
# Yante Maten
# Int64Index([24], dtype='int64')
# Wesley Matthews
# Int64Index([24], dtype='int64')
# Wesley Matthews
# Int64Index([24], dtype='int64')
# Wesley Matthews
# Int64Index([24], dtype='int64')
# Wesley Matthews
# Int64Index([15], dtype='int64')
# Luc Mbah a Moute
# Int64Index([], dtype='int64')
# Tahjere McCall
# Int64Index([18], dtype='int64')
# Patrick McCaw
# Int64Index([18], dtype='int64')
# Patrick McCaw
# Int64Index([18], dtype='int64')
# Patrick McCaw
# Int64Index([18], dtype='int64')
# CJ McCollum
# Int64Index([18], dtype='int64')
# T.J. McConnell
# Int64Index([38], dtype='int64')
# Doug McDermott
# Int64Index([17], dtype='int64')
# JaVale McGee
# Int64Index([34], dtype='int64')
# Rodney McGruder
# Int64Index([27], dtype='int64')
# Alfonzo McKinnie
# Int64Index([25], dtype='int64')
# Ben McLemore
# Int64Index([], dtype='int64')
# None
# Int64Index([], dtype='int64')
# Jordan McRae
# Int64Index([35], dtype='int64')
# Jodie Meeks
# Int64Index([25], dtype='int64')
# Salah Mejri
# Int64Index([42], dtype='int64')
# De'Anthony Melton
# Int64Index([4], dtype='int64')
# Chimezie Metu
# Int64Index([6], dtype='int64')
# Khris Middleton
# Int64Index([23], dtype='int64')
# C.J. Miles
# Int64Index([23], dtype='int64')
# C.J. Miles
# Int64Index([23], dtype='int64')
# C.J. Miles
# Int64Index([14], dtype='int64')
# Darius Miller
# Int64Index([30], dtype='int64')
# Malcolm Miller
# Int64Index([28], dtype='int64')
# Patty Mills
# Int64Index([12], dtype='int64')
# Paul Millsap
# Int64Index([], dtype='int64')
# Shake Milton
# Int64Index([], dtype='int64')
# Nikola Mirotić
# Int64Index([], dtype='int64')
# Nikola Mirotić
# Int64Index([], dtype='int64')
# Nikola Mirotić
# Int64Index([11], dtype='int64')
# Donovan Mitchell
# Int64Index([], dtype='int64')
# Naz Mitrou-Long
# Int64Index([37], dtype='int64')
# Malik Monk
# Int64Index([], dtype='int64')
# Greg Monroe
# Int64Index([], dtype='int64')
# Greg Monroe
# Int64Index([], dtype='int64')
# Greg Monroe
# Int64Index([], dtype='int64')
# Greg Monroe
# Int64Index([13], dtype='int64')
# E'Twaun Moore
# Int64Index([], dtype='int64')
# Eric Moreland
# Int64Index([], dtype='int64')
# Eric Moreland
# Int64Index([], dtype='int64')
# Eric Moreland
# Int64Index([8], dtype='int64')
# Jaylen Morris
# Int64Index([], dtype='int64')
# None
# Int64Index([], dtype='int64')
# Marcus Morris
# Int64Index([33], dtype='int64')
# Markieff Morris
# Int64Index([33], dtype='int64')
# Markieff Morris
# Int64Index([33], dtype='int64')
# Markieff Morris
# Int64Index([25], dtype='int64')
# Monte Morris
# Int64Index([], dtype='int64')
# Donatas Motiejūnas
# Int64Index([], dtype='int64')
# Johnathan Motley
# Int64Index([16], dtype='int64')
# Emmanuel Mudiay
# Int64Index([33], dtype='int64')
# Jamal Murray
# Int64Index([], dtype='int64')
# Džanan Musa
# Int64Index([40], dtype='int64')
# Mike Muscala
# Int64Index([40], dtype='int64')
# Mike Muscala
# Int64Index([40], dtype='int64')
# Mike Muscala
# Int64Index([35], dtype='int64')
# Sviatoslav Mykhailiuk
# Int64Index([35], dtype='int64')
# Sviatoslav Mykhailiuk
# Int64Index([35], dtype='int64')
# Sviatoslav Mykhailiuk
# Int64Index([1], dtype='int64')
# Abdel Nader
# Int64Index([9], dtype='int64')
# Larry Nance Jr.
# Int64Index([28], dtype='int64')
# Shabazz Napier
# Int64Index([17], dtype='int64')
# Raul Neto
# Int64Index([3], dtype='int64')
# Georges Niang
# Int64Index([37], dtype='int64')
# Joakim Noah
# Int64Index([37], dtype='int64')
# Nerlens Noel
# Int64Index([42], dtype='int64')
# Dirk Nowitzki
# Int64Index([18], dtype='int64')
# Frank Ntilikina
# Int64Index([], dtype='int64')
# James Nunnally
# Int64Index([], dtype='int64')
# James Nunnally
# Int64Index([], dtype='int64')
# James Nunnally
# Int64Index([], dtype='int64')
# None
# Int64Index([], dtype='int64')
# Jusuf Nurkić
# Int64Index([11], dtype='int64')
# David Nwaba
# Int64Index([0], dtype='int64')
# Royce O'Neale
# Int64Index([8], dtype='int64')
# Kyle O'Quinn
# Int64Index([20], dtype='int64')
# Semi Ojeleye
# Int64Index([22], dtype='int64')
# Jahlil Okafor
# Int64Index([34], dtype='int64')
# Elie Okobo
# Int64Index([16], dtype='int64')
# Josh Okogie
# Int64Index([42], dtype='int64')
# Victor Oladipo
# Int64Index([12], dtype='int64')
# Kelly Olynyk
# Int64Index([23], dtype='int64')
# Cedi Osman
# Int64Index([5], dtype='int64')
# Kelly Oubre Jr.
# Int64Index([5], dtype='int64')
# Kelly Oubre Jr.
# Int64Index([5], dtype='int64')
# Kelly Oubre Jr.
# Int64Index([26], dtype='int64')
# Zaza Pachulia
# Int64Index([3], dtype='int64')
# Jabari Parker
# Int64Index([3], dtype='int64')
# Jabari Parker
# Int64Index([3], dtype='int64')
# Jabari Parker
# Int64Index([39], dtype='int64')
# Tony Parker
# Int64Index([33], dtype='int64')
# Chandler Parsons
# Int64Index([27], dtype='int64')
# Patrick Patterson
# Int64Index([26], dtype='int64')
# Justin Patton
# Int64Index([1], dtype='int64')
# Chris Paul
# Int64Index([3], dtype='int64')
# Cameron Payne
# Int64Index([3], dtype='int64')
# Cameron Payne
# Int64Index([3], dtype='int64')
# Cameron Payne
# Int64Index([], dtype='int64')
# None
# Int64Index([15], dtype='int64')
# Elfrid Payton
# Int64Index([], dtype='int64')
# Gary Payton II
# Int64Index([], dtype='int64')
# Theo Pinson
# Int64Index([8], dtype='int64')
# Mason Plumlee
# Int64Index([13], dtype='int64')
# Miles Plumlee
# Int64Index([], dtype='int64')
# Jakob Pöltl
# Int64Index([5], dtype='int64')
# Quincy Pondexter
# Int64Index([], dtype='int64')
# Otto Porter
# Int64Index([], dtype='int64')
# Otto Porter
# Int64Index([], dtype='int64')
# Otto Porter
# Int64Index([39], dtype='int64')
# Bobby Portis
# Int64Index([39], dtype='int64')
# Bobby Portis
# Int64Index([39], dtype='int64')
# Bobby Portis
# Int64Index([4], dtype='int64')
# Dwight Powell
# Int64Index([8], dtype='int64')
# Norman Powell
# Int64Index([0], dtype='int64')
# Alex Poythress
# Int64Index([15], dtype='int64')
# Zhou Qi
# Int64Index([7], dtype='int64')
# Ivan Rabb
# Int64Index([2], dtype='int64')
# Chasson Randle
# Int64Index([19], dtype='int64')
# Julius Randle
# Int64Index([], dtype='int64')
# J.J. Redick
# Int64Index([], dtype='int64')
# Davon Reed
# Int64Index([], dtype='int64')
# Cameron Reynolds
# Int64Index([9], dtype='int64')
# Josh Richardson
# Int64Index([], dtype='int64')
# None
# Int64Index([20], dtype='int64')
# Malachi Richardson
# Int64Index([1], dtype='int64')
# Austin Rivers
# Int64Index([1], dtype='int64')
# Austin Rivers
# Int64Index([1], dtype='int64')
# Austin Rivers
# Int64Index([], dtype='int64')
# Devin Robinson
# Int64Index([], dtype='int64')
# Duncan Robinson
# Int64Index([19], dtype='int64')
# Glenn Robinson III
# Int64Index([13], dtype='int64')
# Jerome Robinson
# Int64Index([36], dtype='int64')
# Mitchell Robinson
# Int64Index([12], dtype='int64')
# Rajon Rondo
# Int64Index([23], dtype='int64')
# Derrick Rose
# Int64Index([40], dtype='int64')
# Terrence Ross
# Int64Index([12], dtype='int64')
# Terry Rozier
# Int64Index([34], dtype='int64')
# Ricky Rubio
# Int64Index([1], dtype='int64')
# D'Angelo Russell
# Int64Index([28], dtype='int64')
# Domantas Sabonis
# Int64Index([], dtype='int64')
# Brandon Sampson
# Int64Index([], dtype='int64')
# JaKarr Sampson
# Int64Index([], dtype='int64')
# Dario Šarić
# Int64Index([], dtype='int64')
# Dario Šarić
# Int64Index([], dtype='int64')
# Dario Šarić
# Int64Index([], dtype='int64')
# Tomáš Satoranský
# Int64Index([], dtype='int64')
# Dennis Schröder
# Int64Index([14], dtype='int64')
# Mike Scott
# Int64Index([14], dtype='int64')
# Mike Scott
# Int64Index([14], dtype='int64')
# Mike Scott
# Int64Index([], dtype='int64')
# None
# Int64Index([35], dtype='int64')
# Thabo Sefolosha
# Int64Index([39], dtype='int64')
# Wayne Selden
# Int64Index([39], dtype='int64')
# Wayne Selden
# Int64Index([39], dtype='int64')
# Wayne Selden
# Int64Index([20], dtype='int64')
# Collin Sexton
# Int64Index([40], dtype='int64')
# Landry Shamet
# Int64Index([40], dtype='int64')
# Landry Shamet
# Int64Index([40], dtype='int64')
# Landry Shamet
# Int64Index([35], dtype='int64')
# Iman Shumpert
# Int64Index([35], dtype='int64')
# Iman Shumpert
# Int64Index([35], dtype='int64')
# Iman Shumpert
# Int64Index([24], dtype='int64')
# Pascal Siakam
# Int64Index([], dtype='int64')
# Jordan Sibert
# Int64Index([12], dtype='int64')
# Ben Simmons
# Int64Index([17], dtype='int64')
# Jonathon Simmons
# Int64Index([17], dtype='int64')
# Jonathon Simmons
# Int64Index([17], dtype='int64')
# Jonathon Simmons
# Int64Index([], dtype='int64')
# Kobi Simmons
# Int64Index([36], dtype='int64')
# Anfernee Simons
# Int64Index([27], dtype='int64')
# Marcus Smart
# Int64Index([24], dtype='int64')
# Dennis Smith Jr.
# Int64Index([24], dtype='int64')
# Dennis Smith Jr.
# Int64Index([24], dtype='int64')
# Dennis Smith Jr.
# Int64Index([18], dtype='int64')
# Ish Smith
# Int64Index([], dtype='int64')
# J.R. Smith
# Int64Index([28], dtype='int64')
# Jason Smith
# Int64Index([28], dtype='int64')
# Jason Smith
# Int64Index([28], dtype='int64')
# Jason Smith
# Int64Index([28], dtype='int64')
# Jason Smith
# Int64Index([34], dtype='int64')
# Zhaire Smith
# Int64Index([37], dtype='int64')
# Tony Snell
# Int64Index([42], dtype='int64')
# Ray Spalding
# Int64Index([42], dtype='int64')
# Ray Spalding
# Int64Index([42], dtype='int64')
# Ray Spalding
# Int64Index([14], dtype='int64')
# Omari Spellman
# Int64Index([], dtype='int64')
# None
# Int64Index([26], dtype='int64')
# Nik Stauskas
# Int64Index([26], dtype='int64')
# Nik Stauskas
# Int64Index([26], dtype='int64')
# Nik Stauskas
# Int64Index([], dtype='int64')
# D.J. Stephens
# Int64Index([9], dtype='int64')
# Lance Stephenson
# Int64Index([], dtype='int64')
# Edmond Sumner
# Int64Index([38], dtype='int64')
# Caleb Swanigan
# Int64Index([38], dtype='int64')
# Caleb Swanigan
# Int64Index([38], dtype='int64')
# Caleb Swanigan
# Int64Index([7], dtype='int64')
# Jayson Tatum
# Int64Index([9], dtype='int64')
# Jeff Teague
# Int64Index([27], dtype='int64')
# Garrett Temple
# Int64Index([27], dtype='int64')
# Garrett Temple
# Int64Index([27], dtype='int64')
# Garrett Temple
# Int64Index([], dtype='int64')
# Miloš Teodosić
# Int64Index([], dtype='int64')
# Jared Terrell
# Int64Index([], dtype='int64')
# Emanuel Terry
# Int64Index([], dtype='int64')
# Emanuel Terry
# Int64Index([], dtype='int64')
# Emanuel Terry
# Int64Index([22], dtype='int64')
# Daniel Theis
# Int64Index([18], dtype='int64')
# Isaiah Thomas
# Int64Index([13], dtype='int64')
# Khyri Thomas
# Int64Index([0], dtype='int64')
# Lance Thomas
# Int64Index([11], dtype='int64')
# Klay Thompson
# Int64Index([17], dtype='int64')
# Tristan Thompson
# Int64Index([18], dtype='int64')
# Sindarius Thornwell
# Int64Index([3], dtype='int64')
# Anthony Tolliver
# Int64Index([31], dtype='int64')
# Karl-Anthony Towns
# Int64Index([], dtype='int64')
# None
# Int64Index([5], dtype='int64')
# Gary Trent Jr.
# Int64Index([39], dtype='int64')
# Allonzo Trier
# Int64Index([29], dtype='int64')
# P.J. Tucker
# Int64Index([15], dtype='int64')
# Evan Turner
# Int64Index([38], dtype='int64')
# Myles Turner
# Int64Index([0], dtype='int64')
# Ekpe Udoh
# Int64Index([], dtype='int64')
# Tyler Ulis
# Int64Index([], dtype='int64')
# Jonas Valančiūnas
# Int64Index([], dtype='int64')
# Jonas Valančiūnas
# Int64Index([], dtype='int64')
# Jonas Valančiūnas
# Int64Index([8], dtype='int64')
# Jarred Vanderbilt
# Int64Index([16], dtype='int64')
# Fred VanVleet
# Int64Index([28], dtype='int64')
# Noah Vonleh
# Int64Index([], dtype='int64')
# Nikola Vučević
# Int64Index([14], dtype='int64')
# Dwyane Wade
# Int64Index([35], dtype='int64')
# Moritz Wagner
# Int64Index([29], dtype='int64')
# Dion Waiters
# Int64Index([23], dtype='int64')
# Kemba Walker
# Int64Index([], dtype='int64')
# Lonnie Walker
# Int64Index([7], dtype='int64')
# John Wall
# Int64Index([30], dtype='int64')
# Tyrone Wallace
# Int64Index([35], dtype='int64')
# Taurean Prince
# Int64Index([], dtype='int64')
# None
# Int64Index([17], dtype='int64')
# Brad Wanamaker
# Int64Index([25], dtype='int64')
# T.J. Warren
# Int64Index([], dtype='int64')
# Julian Washburn
# Int64Index([], dtype='int64')
# Yuta Watanabe
# Int64Index([], dtype='int64')
# Thomas Welsh
# Int64Index([3], dtype='int64')
# Russell Westbrook
# Int64Index([2], dtype='int64')
# Derrick White
# Int64Index([36], dtype='int64')
# Okaro White
# Int64Index([25], dtype='int64')
# Hassan Whiteside
# Int64Index([20], dtype='int64')
# Andrew Wiggins
# Int64Index([41], dtype='int64')
# Alan Williams
# Int64Index([], dtype='int64')
# C.J. Williams
# Int64Index([], dtype='int64')
# Johnathan Williams
# Int64Index([16], dtype='int64')
# Kenrich Williams
# Int64Index([28], dtype='int64')
# Lou Williams
# Int64Index([41], dtype='int64')
# Marvin Williams
# Int64Index([], dtype='int64')
# Robert Williams
# Int64Index([6], dtype='int64')
# Troy Williams
# Int64Index([31], dtype='int64')
# D.J. Wilson
# Int64Index([36], dtype='int64')
# Justise Winslow
# Int64Index([], dtype='int64')
# None
# Int64Index([24], dtype='int64')
# Christian Wood
# Int64Index([24], dtype='int64')
# Christian Wood
# Int64Index([24], dtype='int64')
# Christian Wood
# Int64Index([30], dtype='int64')
# Delon Wright
# Int64Index([30], dtype='int64')
# Delon Wright
# Int64Index([30], dtype='int64')
# Delon Wright
# Int64Index([27], dtype='int64')
# Guerschon Yabusele
# Int64Index([39], dtype='int64')
# Nick Young
# Int64Index([0], dtype='int64')
# Thaddeus Young
# Int64Index([30], dtype='int64')
# Trae Young
# Int64Index([3], dtype='int64')
# Cody Zeller
# Int64Index([], dtype='int64')
# Tyler Zeller
# Int64Index([], dtype='int64')
# Tyler Zeller
# Int64Index([], dtype='int64')
# Tyler Zeller
# Int64Index([], dtype='int64')
# Ante Žižić
# Int64Index([33], dtype='int64')
# Ivica Zubac
# Int64Index([33], dtype='int64')
# Ivica Zubac
# Int64Index([33], dtype='int64')
# Ivica Zubac
